# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    Z = 24.44321494051954
    if abs(x) > 7:
        return 0
    elif abs(x) > 3:
        return 3 * (1 - (x / 7) ** 2) ** 0.5 / Z
    elif abs(x) > 1:
        return (
            (3 - abs(x)) / 2 -
            3/7 * 10**0.5 * ((3 - x**2 + 2*abs(x))**0.5 - 2)
           ) / Z
    elif abs(x) > 0.75:
        return (9 - 8 * abs(x)) / Z
    elif abs(x) > 0.5:
        return (3 * abs(x) + 0.75) / Z
    else:
        return 2.25 / Z

# %%
def g(x):
    return np.random.normal(x, 2)

# %%
def simulation(steps, initial_val):
    samples=[]
    X = initial_val
    for i in range(steps):
        Y = g(X)
        if np.random.uniform(0,1) < min(1, f(Y)/f(X)):
            samples.append(Y)
            X=Y
    return samples

# %%
batman_samples=simulation(100000, 0)

# %%
plt.figure(figsize=(16, 9))
plt.hist(batman_samples, bins=70, density=True)
x_axis = np.linspace(-8, 8, 1000)
y_axis = [f(x) for x in x_axis]
plt.plot(x_axis, y_axis)
plt.show()

# %%
import networkx as nx
from pylab import *

# %%
print(nx.__version__)
# Out:
# 2.4

# %%
tesseract = nx.hypercube_graph(4)

# %%
nx.draw(tesseract)

# %%
ladder = nx.ladder_graph(5)
nx.draw(ladder)

# %%
barbell = nx.barbell_graph(20, 20)
nx.draw(barbell)

# %%
wheel = nx.wheel_graph(100)
nx.draw(wheel)
